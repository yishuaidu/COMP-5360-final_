# %%
## scraping data part 1 ## 
from bs4 import BeautifulSoup
import requests, bs4


## this calss only work with webside https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview
class Las_Vegas_zip_code():
    """
    This class is only work with webside:
    
    https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview
    
    
    The main function of this calss is get all zip code of Las Vegas's links. 
    
        
    
    
    """

    def __init__(self,*args,link,**kwargs):
        #super(Montgomery_County,self).__init__(*args,**kwargs)
        
        if link == "https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview":
            self.__link = link
        else:
            raise TypeError("plz have a right web, https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview")
        
    @property
    def link(self):
        return self.__link
    
    
    
    def get_web_soup(self):
        """
        This function get the soup of a link
        
        return bs4.BeautifulSoup type 
        
        """
        web = requests.get(self.link)
        soup = BeautifulSoup(web.text, "html.parser")
        return soup
    
    def get_all_zip_code_link(self):
        
        """
        This function get all zip code's link from a link
        
        return a dic type
        """
        
        dic ={}   
        zip_code =[]
        soup = self.get_web_soup()
        for d in soup.find_all(class_="info-table-tr row"):
                for i in d.find_all(class_= "b info-table-title-td col-sm-3"):
                    if (i.get_text() == "ZIP Codes: " ):
                        for n in d.find_all("a"):
                            name = n.get_text()
                            zip_code.append(name)
                            l = "http://statisticalatlas.com" + n.get("href")
                            dic[name] = (name,l)
        return dic
    
    
    def __str__(self):
        """
        This function shows information 
        """
        x =  self.link
        return x

# %%
class Las_Vegas_Crawler(Las_Vegas_zip_code):
    """
    This derived class that inherits from this parent class which is Las_Vegas class.
    
    """
    
    def __init__(self,*args,name,dic,**kwargs):
        
        super(Las_Vegas_Crawler,self).__init__(*args,**kwargs)
        
        self.__name = name
        self.__dic = dic
     
    
    @property
    def name(self):
        return self.__name
    
    
    @property
    def dic(self):
        return self.__dic
    
    
    
    def get_zipCode_link(self):
        
        if (not self.name in self.dic):
            print("Unknown zip code " + self.name)
        else:
            url = self.dic[self.name][1]
            
            
        return url
        
        
    
    
    def getZipCode(self):
        """ 
        Retrieve a website based on the subject short name and return it as a BeautifulSoup object. 
        Assumes an existing subjects dictionary.
        """
        if (not self.name in self.dic):
            print("Unknown zip code " + self.name)
        else:
            url = self.dic[self.name][1]
            web = requests.get(url)
            web.encoding='utf8'
            nameSoup = bs4.BeautifulSoup(web.text,"html.parser")
            return nameSoup
        
        
        
         ## Get Household Income ##

    def getIncome(self):    
        soup = self.getZipCode()
        #get webside of Household Income
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Household Income"):
                l= "http://statisticalatlas.com" + i.get("href")

        # read webside of Household Income  
        web = requests.get(l)
        web.encoding='utf8'
        income = bs4.BeautifulSoup(web.text,"html.parser")

        qq= income.find(class_ = "figure-contents")
        qq = qq.find_all("title")

        ## we choose the median as household income in this zip code
        ## we can see 100% as median of income, so income is above 100%
        count =0 
        for i in qq:
            if (i.text.strip() == "100.000%"):
                break
            count = count +1

        # output income
            return qq[count-1].text.strip()   
    
    
    
    
    
        ## Get Educational Attainment##

    def getEdu(self):    
        soup = self.getZipCode()
        #get webside of Educational Attainment
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Educational Attainment"):
                l= "http://statisticalatlas.com" + i.get("href")

        # read webside of Educational Attainment  
        web = requests.get(l)
        web.encoding='utf8'
        income = bs4.BeautifulSoup(web.text,"html.parser")

        qq= income.find(class_ = "figure-contents")
        qq = qq.find_all("text")

        ## we choose the counts of higher degree as highger educational Attainment in this zip code
        ## find the number of counts 

        return qq[-5].text.strip()
    
    
    
    def getEmployment (self):
        soup = self.getZipCode()
        #get webside of Educational Attainment
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Employment Status"):
                l= "http://statisticalatlas.com" + i.get("href")

        # read webside of Employment Status  
        web = requests.get(l)
        web.encoding='utf8'
        income = bs4.BeautifulSoup(web.text,"html.parser")

        qq= income.find(class_ = "figure-contents")
        qq = qq.find_all("text")

        ## we choose the counts of Employment  in this zip code
        ## find the number of counts 

        return qq[-5].text.strip()
    
    def getRace_W (self):
        soup = self.getZipCode()
        #get webside of race
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Race and Ethnicity"):
                l= "http://statisticalatlas.com" + i.get("href")
        # read webside of race  
        web = requests.get(l)
        web.encoding='utf8'
        race = bs4.BeautifulSoup(web.text,"html.parser")
        qq= race.find(class_ = "figure-contents")
        qq = qq.find_all(fill="#000")
        ## we choose the counts of race of white people  in this zip code
        ## find the number of counts 

        return qq[-11].text.strip()
    
    def getRace_H (self):
        soup = self.getZipCode()
        #get webside of race
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Race and Ethnicity"):
                l= "http://statisticalatlas.com" + i.get("href")
        # read webside of race  
        web = requests.get(l)
        web.encoding='utf8'
        race = bs4.BeautifulSoup(web.text,"html.parser")
        qq= race.find(class_ = "figure-contents")
        qq = qq.find_all(fill="#000")

        ## we choose the counts of race of white people  in this zip code
        ## find the number of counts 
        return qq[-9].text.strip()

    def getRace_B (self):
        soup = self.getZipCode()
        #get webside of race
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Race and Ethnicity"):
                l= "http://statisticalatlas.com" + i.get("href")
        # read webside of race  
        web = requests.get(l)
        web.encoding='utf8'
        race = bs4.BeautifulSoup(web.text,"html.parser")
        qq= race.find(class_ = "figure-contents")
        qq = qq.find_all(fill="#000")
        ## we choose the counts of race of white people  in this zip code
        ## find the number of counts 
        return qq[-7].text.strip()

    def getRace_A (self):
        soup = self.getZipCode()
        #get webside of race
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Race and Ethnicity"):
                l= "http://statisticalatlas.com" + i.get("href")
        # read webside of race  
        web = requests.get(l)
        web.encoding='utf8'
        race = bs4.BeautifulSoup(web.text,"html.parser")
        qq= race.find(class_ = "figure-contents")
        qq = qq.find_all(fill="#000")
        ## we choose the counts of race of white people  in this zip code
        ## find the number of counts 
        return qq[-5].text.strip()

    def getRace_M (self):
        soup = self.getZipCode()
        #get webside of race
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Race and Ethnicity"):
                l= "http://statisticalatlas.com" + i.get("href")
        # read webside of race  
        web = requests.get(l)
        web.encoding='utf8'
        race = bs4.BeautifulSoup(web.text,"html.parser")
        qq= race.find(class_ = "figure-contents")
        qq = qq.find_all(fill="#000")
        ## we choose the counts of race of white people  in this zip code
        ## find the number of counts 
        return qq[-3].text.strip()

    def getRace_o (self):
        soup = self.getZipCode()
        #get webside of race
        for row in soup.find_all(class_ = "nav nav-stacked"):
                b= row.find_all("a")
        for i in b:
            if ( i.text.strip() == "Race and Ethnicity"):
                l= "http://statisticalatlas.com" + i.get("href")
        # read webside of race  
        web = requests.get(l)
        web.encoding='utf8'
        race = bs4.BeautifulSoup(web.text,"html.parser")
        qq= race.find(class_ = "figure-contents")
        qq = qq.find_all(fill="#000")
        ## we choose the counts of race of white people  in this zip code
        ## find the number of counts 
        return qq[-1].text.strip()
    
    def Population(self):
        a = self.getZipCode()
        for row in a.find_all(alt="Population",title="Population"):
            for i in row.find_all("td"):
                return i.text.strip()
            
            
    def Households(self):
        a = self.getZipCode()
        for row in a.find_all(alt="Households",title="Households"):
            for i in row.find_all("td"):
                return i.text.strip()
             
        


    def __str__(self):
        print( self.name)
        print("link: "  + self.get_zipCode_link())
        print("Population: " + self.Population())
        print("Households: " + self.Households())
        print("Income: "+ self.getIncome())
        print("High Eduction: " + self.getEdu())
        print("Employment: " + self.getEmployment())
        print("White people: " + self.getRace_W())
        print("Hispanic people: " + self.getRace_H())
        print("Black people: " + self.getRace_B())
        print("Asian people: " + self.getRace_A())
        print("Mixed people: " + self.getRace_M())
        print("Other people: " + self.getRace_o())

# %%
## just only working for specific website

link = Las_Vegas_zip_code(link = "https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview")
soup=link.get_web_soup()
ALL_zip_code = link.get_all_zip_code_link()

# %%
## example of one zip code 
#a = Las_Vegas_Crawler(name='89002',dic=ALL_zip_code,link ="https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview" )
#a.__str__()

# %%
zip_=[]
Population =[]
income =[]
edu_high =[]
Emp=[]
Race_w=[]
Race_h=[]
Race_b=[]
Race_a=[]
Race_m=[]
Race_o=[]

Households=[]


count = 0

print("****** Crawler runing *******")
all_zip_list = list(ALL_zip_code.keys())

## useless zip code
all_zip_list.remove('89026')
all_zip_list.remove('89191')

for i in all_zip_list:
    a = Las_Vegas_Crawler(name=i,dic=ALL_zip_code,link ="https://statisticalatlas.com/metro-area/Nevada/Las-Vegas/Overview" )
    print(str(count+1)+"/"+str(len(all_zip_list)) + " ****** " + str(i))
    zip_.append(i)
    Population.append(a.Population())
    income.append(a.getIncome())
    edu_high.append(a.getEdu())
    Emp.append(a.getEmployment())
    Race_w.append(a.getRace_W())
    Race_h.append(a.getRace_H())
    Race_b.append(a.getRace_B())
    Race_a.append(a.getRace_A())
    Race_m.append(a.getRace_M())
    Race_o.append(a.getRace_o())

    Households.append(a.Households())
    count = count +1
    
print("****** Crawler End *******")
# Out:
# ****** Crawler runing *******
# 1/71 ****** 89002
# 2/71 ****** 89004
# 3/71 ****** 89005
# 4/71 ****** 89007
# 5/71 ****** 89011
# 6/71 ****** 89012
# 7/71 ****** 89014
# 8/71 ****** 89015
# 9/71 ****** 89018
# 10/71 ****** 89019
# 11/71 ****** 89021
# 12/71 ****** 89025
# 13/71 ****** 89027
# 14/71 ****** 89029
# 15/71 ****** 89030
# 16/71 ****** 89031
# 17/71 ****** 89032
# 18/71 ****** 89039
# 19/71 ****** 89040
# 20/71 ****** 89044
# 21/71 ****** 89046
# 22/71 ****** 89052
# 23/71 ****** 89054
# 24/71 ****** 89074
# 25/71 ****** 89081
# 26/71 ****** 89084
# 27/71 ****** 89085
# 28/71 ****** 89086
# 29/71 ****** 89101
# 30/71 ****** 89102
# 31/71 ****** 89103
# 32/71 ****** 89104
# 33/71 ****** 89106
# 34/71 ****** 89107
# 35/71 ****** 89108
# 36/71 ****** 89109
# 37/71 ****** 89110
# 38/71 ****** 89113
# 39/71 ****** 89115
# 40/71 ****** 89117
# 41/71 ****** 89118
# 42/71 ****** 89119
# 43/71 ****** 89120
# 44/71 ****** 89121
# 45/71 ****** 89122
# 46/71 ****** 89123
# 47/71 ****** 89124
# 48/71 ****** 89128
# 49/71 ****** 89129
# 50/71 ****** 89130
# 51/71 ****** 89131
# 52/71 ****** 89134
# 53/71 ****** 89135
# 54/71 ****** 89138
# 55/71 ****** 89139
# 56/71 ****** 89141
# 57/71 ****** 89142
# 58/71 ****** 89143
# 59/71 ****** 89144
# 60/71 ****** 89145
# 61/71 ****** 89146
# 62/71 ****** 89147
# 63/71 ****** 89148
# 64/71 ****** 89149
# 65/71 ****** 89156
# 66/71 ****** 89161
# 67/71 ****** 89166
# 68/71 ****** 89169
# 69/71 ****** 89178
# 70/71 ****** 89179
# 71/71 ****** 89183
# ****** Crawler End *******

# %%
import pandas as pd
df1 = pd.DataFrame({"zip":zip_ , "Population":Population,"income":income,"edu_high":edu_high,"Emp":Emp,"Race_w":Race_w,"Race_h":Race_h,"Race_b":Race_b,"Race_a":Race_a,"Race_m":Race_m,"Race_o":Race_o,"Households":Households})
#df1.to_csv("df_zipcode.csv")

df1.head()
# Out:
#      zip Population           income edu_high    Emp Race_w Race_h Race_b  \
# 0  89002     34,343  $196,338.000000    7,825  15.7k  26.1k  4,746  1,027
# 1  89004        345  $250,001.000000      168    177    329     10      0
# 2  89005     15,373  $188,448.000000    4,269  6,041  13.0k  1,408     51
# 3  89007      1,423  $104,827.000000       65    489    772    605      0
# 4  89011     21,506  $181,331.000000    4,964  10.6k  12.8k  4,081  2,121
#
#   Race_a Race_m Race_o Households
# 0  1,403    955    124     11,431
# 1      6      0      0        144
# 2    401    386    172      6,256
# 3      0      0     46        349
# 4  1,624    820    106      8,290

# %%
from transform import transform_number as tn  ## this is the transform module that we built

df_zip = pd.read_csv("df_zipcode.csv")
### Population
df_zip['Population'] = tn.clean_comma(df_zip['Population']).astype("int")

## num_high_edu
df_zip['edu_high'] = tn.clean_comma(df_zip['edu_high'])
convert =[]
for i in df_zip['edu_high']:
    convert.append(tn.convert_k (i))
    
df_zip['edu_high'] =convert


##Households
df_zip['Households'] = tn.clean_comma(df_zip['Households']).astype("int")

## Race
for ii in ['Race_w','Race_h','Race_b','Race_a','Race_m','Race_o']:
    df_zip[ii] = tn.clean_comma(df_zip[ii])
    convert =[]
    for i in df_zip[ii]:
        convert.append(tn.convert_k (i))
    df_zip[ii] =convert    

## Employment

df_zip['Emp'] = tn.clean_comma(df_zip['Emp'])
convert =[]
for i in df_zip['Emp']:
    convert.append(tn.convert_k (i))
df_zip['Emp'] =convert 

## Income
df_zip['income'] = tn.convert_dollar(df_zip['income'])

# %%
df_zip
# Out:
#     Unnamed: 0    zip  Population  income  edu_high    Emp  Race_w  Race_h  \
# 0            0  89002       34343  196338      7825  15700   26100    4746
# 1            1  89004         345  250001       168    177     329      10
# 2            2  89005       15373  188448      4269   6041   13000    1408
# 3            3  89007        1423  104827        65    489     772     605
# 4            4  89011       21506  181331      4964  10600   12800    4081
# 5            5  89012       31614  220427     10100  14700   21900    4049
# 6            6  89014       38916  170423      8946  19500   22900    8413
# 7            7  89015       41738  152637      7038  17100   28600    7111
# 8            8  89018        4797   93602       347    289    1905    1152
# 9            9  89019        1762  147322        61    775    1420     203
# 10          10  89021        3322  182685       569   1300    3012     303
# 11          11  89025        1589  175570       132    582     834     518
# 12          12  89027       16953  129305      3657   5356   12600    3557
# 13          13  89029        7823  104748      1520   2266    5859    1021
# 14          14  89030       47895   93276      1934  17000    4890   34100
# 15          15  89031       66586  157386     10900  31200   24500   22700
# 16          16  89032       43967  134948      5559  19600    9683   17000
# 17          17  89039         143   76225        14     22     124       5
# 18          18  89040        3334  148825       545   1143    2978     168
# 19          19  89044       18587  212327      7539   8034   14000    1210
# 20          20  89046         398   57194        72    146     384      14
# 21          21  89052       51208  250001     18700  23300   33300    7158
# 22          22  89054          48   46875        10     35      48       0
# 23          23  89074       49133  230125     14700  25900   32100    8285
# 24          24  89081       34495  154232      5603  14600   10500    9923
# 25          25  89084       24583  202111      7340  10700   12300    4476
# 26          26  89085        4369  175820       947   2094    2459     854
# 27          27  89086        5787  125386       880   2525    1759    1805
# 28          28  89101       40673   91475      3019  14400    8658   23000
# 29          29  89102       37272  128171      5140  16000   10600   18300
# ..         ...    ...         ...     ...       ...    ...     ...     ...
# 41          41  89119       50333  117859      7245  24300   15600   21600
# 42          42  89120       24830  170696      5412  12000   12100    7459
# 43          43  89121       63884  131266      8929  28100   26100   26600
# 44          44  89122       49800  124047      7516  22800   17100   18900
# 45          45  89123       57322  181696     14600  30900   32299   11500
# 46          46  89124         783  250001       313    428     620      71
# 47          47  89128       37110  187104      9564  18000   18000    8622
# 48          48  89129       55164  193605     14500  27900   32800    9211
# 49          49  89130       35480  168484      7765  16200   20000    7353
# 50          50  89131       46129  206955     12300  21700   30000    7197
# 51          51  89134       25053  234601     10100   8352   19200    2170
# 52          52  89135       25919  250001     11100  12100   17600    2631
# 53          53  89138       14753  250001      5671   6949    8924    1951
# 54          54  89139       37869  184123     10000  20800   12600    8301
# 55          55  89141       29182  240076      8201  14800   14900    4780
# 56          56  89142       34834  136603      4711  16200    8184   17400
# 57          57  89143       12778  192977      3144   5738    8002    2195
# 58          58  89144       18858  250001      6490   8437   12000    2267
# 59          59  89145       25193  219090      6073  12100   13800    7124
# 60          60  89146       17896  166520      3716   7988    7500    5553
# 61          61  89147       52646  160290     11700  26300   22000   10600
# 62          62  89148       47938  167138     13100  25200   20200    7950
# 63          63  89149       35120  207908      9592  17000   22400    4449
# 64          64  89156       29132  135845      2893  12200    9107   13400
# 65          65  89161          52       0         0     52      38      14
# 66          66  89166       17783  178758      4421   7364    9851    3061
# 67          67  89169       22421  125360      3016  10700    6347   10400
# 68          68  89178       35241  203397     10500  19300   15800    5355
# 69          69  89179        5178  203279      1670   2686    2355     922
# 70          70  89183       38974  163121      9278  20400   18400    7781
#
#     Race_b  Race_a  Race_m  Race_o  Households
# 0     1027    1403     955     124       11431
# 1        0       6       0       0         144
# 2       51     401     386     172        6256
# 3        0       0       0      46         349
# 4     2121    1624     820     106        8290
# 5     1544    2515    1311     254       12918
# 6     2757    2286    1567     964       15514
# 7     3397    1075    1012     499       14782
# 8     1397      53     183     107         379
# 9       42      93       4       0         837
# 10       0       7       0       0         929
# 11       2       8       7     220         387
# 12     117     264     202     210        7379
# 13     438     164     262      79        4011
# 14    7410     686     485     312       13122
# 15   11100    4277    2898    1189       19905
# 16   11900    2774    1723     844       13404
# 17       5       0       0       9         102
# 18      21      11      94      62        1247
# 19     856    2099     294      80        8081
# 20       0       0       0       0         206
# 21    2163    6596    1665     289       20307
# 22       0       0       0       0          25
# 23    2427    3900    1972     464       18994
# 24    9385    2323    1954     432       10035
# 25    3782    2720     759     519        8768
# 26     249     701      60      46        1236
# 27    1704     161     350       8        1926
# 28    6358    1352     927     370       13827
# 29    4228    2811     855     478       14020
# ..     ...     ...     ...     ...         ...
# 41    6596    4319    1469     794       20273
# 42    2268    1928     649     386        9147
# 43    6276    2986    1164     767       23737
# 44    5291    5547    2080     944       17575
# 45    3266    7089    1787    1402       22715
# 46       1      28      32      31         303
# 47    4954    3599    1595     345       14458
# 48    5742    4539    2431     486       19825
# 49    5041    1713    1180     150       12563
# 50    3701    2709    2183     352       15725
# 51    1313    1736     561     101       11679
# 52    1266    3355     996      93       10750
# 53     731    2387     515     245        5007
# 54    3733   10800    1778     688       11793
# 55    2374    5652    1176     254        9627
# 56    3266    4392     963     582       10575
# 57     960     827     700      94        4094
# 58    1487    2501     454     129        7132
# 59    1655    1658     809     161        9442
# 60    1784    2462     523      74        6411
# 61    6622   10000    2477     954       18889
# 62    4021   11600    3314     922       16174
# 63    3629    2323    1790     523       13091
# 64    3729    1426     983     449        9055
# 65       0       0       0       0          44
# 66    2179    1418     927     347        5094
# 67    2971    1848     731     126        8990
# 68    2365    8724    2466     570       11679
# 69     258    1399     228      16        1694
# 70    3745    6034    2492     546       13897
#
# [71 rows x 13 columns]
